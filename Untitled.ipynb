# %%
import pandas as pd
import numpy as np
import datetime
import os
from scripts.f1_scripts import (assign_lap, 
                        get_tires, 
                        get_sector_times,
                        convert_time
                               )

import statsmodels.api as sms
from sklearn.linear_model import LinearRegression
from sklearn.cross_validation import KFold
from sklearn.cross_validation import train_test_split
from sklearn.cross_validation import cross_val_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor

# %%
import matplotlib.pyplot as plt
import seaborn as sn
# %matplotlib inline

def assign_color(tire):
    colors = {'Ultra': 'm', 'Super': 'r', 'Soft': 'y', 'Medium': 'w', 'Hard': 'k', 'Intermediate': 'g'}
    return colors[tire]

def assign_ordinal(tire):
    vals = {'Ultra': 1, 'Super': 2, 'Soft': 3, 'Medium': 4, 'Hard': 5, 'Intermediate': 5}
    return vals[tire]
# Out:
# /Users/milesmonaghan/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
# Load driver list as GLOBAL variable
DRIVER_LIST = pd.read_csv('data/drivers.csv')

# %%
def create_race_features(filename):
    year, race_num, track = filename.split('_')
    # Load lap times for all drivers
    lap_data = pd.read_csv('data/lap_history/{filename}_lap_history.csv'.format(filename=filename), header=None)
    lap_times = assign_lap(lap_data)
    lap_times['TIME'] = convert_time(lap_times['TIME'])
    lap_times.sort_values(by=['NO', 'LAP'], inplace=True)

    # Load Tire strategy data
    tire_data = pd.read_csv('data/tire_strategy/{filename}.csv'.format(filename=filename))
    tire_strat = get_tires(tire_data)

    # Join Driver, Name, No. to tire data and sort by No.
    tire_strat = pd.merge(DRIVER_LIST, tire_strat, on='NAME')
    tire_strat.drop(['NAME', 'DRIVER'], axis=1, inplace=True)

    # Append tire data to lap data
    mask = tire_strat.iloc[:,1:].notnull().values
    lap_times['TIRE'] = tire_strat[tire_strat.columns[1:]].values[mask].flatten()
    lap_times['TRACK'] = track
    lap_times['YEAR'] = year
    lap_times['RACE'] = race_num

    return lap_times

# %%
# Create a list of the available races to date that we can use for training
races = os.listdir('data/fia')
races = races[1:]
# Remove bahrain 2015 until data is fixed
races.pop(13)
races
# Out:
# ['2015_10_hungary',
#  '2015_11_belgium',
#  '2015_12_italy',
#  '2015_13_singapore',
#  '2015_14_japan',
#  '2015_15_russia',
#  '2015_16_usa',
#  '2015_17_mexico',
#  '2015_18_brazil',
#  '2015_19_abudhabi',
#  '2015_1_australia',
#  '2015_2_malaysia',
#  '2015_3_china',
#  '2015_5_spain',
#  '2015_6_monaco',
#  '2015_7_canada',
#  '2015_8_austria',
#  '2015_9_britain',
#  '2016_1_australia',
#  '2016_2_bahrain',
#  '2016_3_china']

# %%
# Create DataFrame of all laps for all drivers in all races
list_of_times = []
for race in races:
    lap_times = create_race_features(race)
    list_of_times.append(lap_times)
    print '{} complete.'.format(race)
all_lap_times = pd.concat(list_of_times)
all_lap_times['YEAR'] = all_lap_times['YEAR'].astype(int)
# Out:
# 2015_10_hungary complete.
# 2015_11_belgium complete.
# 2015_12_italy complete.
# 2015_13_singapore complete.
# 2015_14_japan complete.
# 2015_15_russia complete.
# 2015_16_usa complete.
# 2015_17_mexico complete.
# 2015_18_brazil complete.
# 2015_19_abudhabi complete.
# 2015_1_australia complete.
# 2015_2_malaysia complete.
# 2015_3_china complete.
# 2015_5_spain complete.
# 2015_6_monaco complete.
# 2015_7_canada complete.
# 2015_8_austria complete.
# 2015_9_britain complete.
# 2016_1_australia complete.
# 2016_2_bahrain complete.
# 2016_3_china complete.

# %% [markdown]
# ### Commented out cells used to debug loading the data

# %%
# # Load driver list for particular season
# driver_list = pd.read_csv('data/drivers.csv')

# # Load lap times for all drivers
# filename = '2016_3_china'
# lap_data = pd.read_csv('data/lap_history/{filename}_lap_history.csv'.format(filename=filename), header=None)
# lap_times = assign_lap(lap_data)
# lap_times['TIME'] = convert_time(lap_times['TIME'])
# lap_times.sort_values(by=['NO', 'LAP'], inplace=True)
# lap_times.shape

# %%
# # Load Tire strategy data
# tire_data = pd.read_csv('data/tire_strategy/{filename}.csv'.format(filename=filename))
# tire_strat = get_tires(tire_data)
# tire_strat['NAME'].unique;

# %%
# # Join Driver, Name, No. to tire data and sort by No.
# tire_strat = pd.merge(driver_list, tire_strat, on='NAME')
# tire_strat.drop(['NAME', 'DRIVER'], axis=1, inplace=True)
# tire_strat;

# %%
# # Append tire data to lap data
# mask = tire_strat.iloc[:,1:].notnull().values
# # lap_times['TIRE'] = 
# tire_strat[tire_strat.columns[1:]].values[mask].flatten().shape
# # lap_times['TRACK'] = 'Australia'
# # lap_times['YEAR'] = 2016
# # lap_times['RACE'] = 1
# # lap_times

# %%
# for num in lap_times['NO'].unique():
#     print num
#     print lap_times[lap_times['NO'] == num].shape

# %%
# for num in lap_times['NO'].unique():
#     print num
#     print 'Laps: ',tire_strat.ix[tire_strat['NO'] == num].notnull().values.sum() - 1

# %% [markdown]
# ### Add track features to lap features data frame

# %%
# Load Track data
tracks = pd.read_csv('data/track_profiles.csv')
tracks.drop('LAPS', axis=1, inplace=True)
tracks['TRACK'] = tracks['TRACK'].apply(lambda x: x.lower())
tracks.head()

# %%
all_lap_times.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22078 entries, 6 to 1206
# Data columns (total 8 columns):
# NO       22078 non-null object
# GAP      22078 non-null object
# TIME     22078 non-null float64
# LAP      22078 non-null object
# TIRE     22078 non-null object
# TRACK    22078 non-null object
# YEAR     22078 non-null int64
# RACE     22078 non-null object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 1.5+ MB

# %%
tracks.info()

# %%
group1 = all_lap_times.drop(['GAP', 'LAP', 'RACE'], axis=1).groupby(['NO', 'TIRE', 'TRACK', 'YEAR'], as_index=False)
avg_laps = pd.merge(group1.count(), group1.mean(), how='left', on=['NO', 'TIRE', 'TRACK', 'YEAR'])
avg_laps.head()
# Out:
#    NO          TIRE     TRACK  YEAR  TIME_x      TIME_y
# 0   3          Hard   britain  2015      10  108.704100
# 1   3          Hard     japan  2015      51  101.457765
# 2   3          Hard  malaysia  2015      37  108.020270
# 3   3          Hard     spain  2015      23   92.960391
# 4   3  Intermediate       usa  2015      19  119.811789

# %%
group2 = all_lap_times[['NO', 'TIRE', 'TRACK', 'YEAR', 'TIME']].groupby(['NO', 'TIRE', 'TRACK', 'YEAR'])
std_laps = pd.merge(avg_laps, group2.std().reset_index(), how='left', on=['NO', 'TIRE', 'TRACK', 'YEAR'])
std_laps.columns = ['NO', 'TIRE', 'TRACK', 'YEAR', 'COUNT', 'TIME_AVG', 'TIME_STD']
std_laps.head()
# Out:
#    NO          TIRE     TRACK  YEAR  COUNT    TIME_AVG   TIME_STD
# 0   3          Hard   britain  2015     10  108.704100  12.859048
# 1   3          Hard     japan  2015     51  101.457765   4.029347
# 2   3          Hard  malaysia  2015     37  108.020270   4.816685
# 3   3          Hard     spain  2015     23   92.960391   4.620764
# 4   3  Intermediate       usa  2015     19  119.811789   6.734605

# %%
all_lap_times.head()
# Out:
#    NO      GAP    TIME LAP  TIRE    TRACK  YEAR RACE
# 6   3   6.325   99.193   1  Soft  hungary  2015   10
# 26  3   8.887   91.382   2  Soft  hungary  2015   10
# 46  3  10.556   90.333   3  Soft  hungary  2015   10
# 66  3  12.451   89.962   4  Soft  hungary  2015   10
# 86  3  13.664   89.525   5  Soft  hungary  2015   10

# %%
clean_laps = pd.merge(all_lap_times, std_laps, how='left', on=['NO', 'TIRE', 'TRACK', 'YEAR'])
clean_laps.shape
# Out:
# (22078, 11)

# %% [markdown]
# ### Remove rows where lap times are classified as outliers

# %%
clean_df = clean_laps[(clean_laps['TIME'] < (clean_laps['TIME_AVG'] + 4*clean_laps['TIME_STD'])) & 
           (clean_laps['TIME'] > (clean_laps['TIME_AVG'] - 4*clean_laps['TIME_STD']))]
clean_df
# Out:
#        NO      GAP     TIME LAP    TIRE    TRACK  YEAR RACE  COUNT  \
# 0       3   6.325    99.193   1    Soft  hungary  2015   10     48
# 1       3   8.887    91.382   2    Soft  hungary  2015   10     48
# 2       3  10.556    90.333   3    Soft  hungary  2015   10     48
# 3       3  12.451    89.962   4    Soft  hungary  2015   10     48
# 4       3  13.664    89.525   5    Soft  hungary  2015   10     48
# 5       3  15.351    89.663   6    Soft  hungary  2015   10     48
# 6       3  16.816    89.597   7    Soft  hungary  2015   10     48
# 7       3  17.971    89.516   8    Soft  hungary  2015   10     48
# 8       3  19.129    89.429   9    Soft  hungary  2015   10     48
# 9       3  19.620    88.830  10    Soft  hungary  2015   10     48
# 10      3  20.338    88.888  11    Soft  hungary  2015   10     48
# 11      3  21.493    89.433  12    Soft  hungary  2015   10     48
# 12      3  21.719    88.409  13    Soft  hungary  2015   10     48
# 13      3  22.138    88.625  14    Soft  hungary  2015   10     48
# 14      3  22.784    88.717  15    Soft  hungary  2015   10     48
# 15      3  23.550    88.679  16    Soft  hungary  2015   10     48
# 16      3  24.292    88.926  17    Soft  hungary  2015   10     48
# 17      3  24.348    88.804  18    Soft  hungary  2015   10     48
# 18      3  25.271    89.211  19    Soft  hungary  2015   10     48
# 19      3  25.970    89.209  20    Soft  hungary  2015   10     48
# 20      3    PIT     92.192  21    Soft  hungary  2015   10     48
# 21      3  41.536   106.428  22  Medium  hungary  2015   10     21
# 22      3  28.918    88.345  23  Medium  hungary  2015   10     21
# 23      3  29.910    88.378  24  Medium  hungary  2015   10     21
# 24      3  31.639    89.096  25  Medium  hungary  2015   10     21
# 25      3  32.541    88.407  26  Medium  hungary  2015   10     21
# 26      3  33.412    88.419  27  Medium  hungary  2015   10     21
# 27      3  34.133    88.732  28  Medium  hungary  2015   10     21
# 28      3  36.172    89.692  29  Medium  hungary  2015   10     21
# 29      3  37.046    88.696  30  Medium  hungary  2015   10     21
# ...    ..      ...      ...  ..     ...      ...   ...  ...    ...
# 22048  94  59.711   104.387  26    Soft    china  2016    3     43
# 22049  94    PIT    109.959  27    Soft    china  2016    3     43
# 22050  94  90.256   122.563  28    Soft    china  2016    3     43
# 22051  94  91.230   102.331  29    Soft    china  2016    3     43
# 22052  94  92.306   102.640  30    Soft    china  2016    3     43
# 22053  94  93.134   103.007  31    Soft    china  2016    3     43
# 22054  94  94.321   103.065  32    Soft    china  2016    3     43
# 22055  94  96.032   104.005  33    Soft    china  2016    3     43
# 22056  94  97.101   103.114  34    Soft    china  2016    3     43
# 22057  94  98.249   103.563  35    Soft    china  2016    3     43
# 22058  94  93.915   103.439  36    Soft    china  2016    3     43
# 22059  94  77.236   103.644  37    Soft    china  2016    3     43
# 22060  94  80.327   103.509  38    Soft    china  2016    3     43
# 22061  94  82.205   103.501  39    Soft    china  2016    3     43
# 22062  94  84.741   103.598  40    Soft    china  2016    3     43
# 22063  94  87.305   103.964  41    Soft    china  2016    3     43
# 22064  94  90.484   104.017  42    Soft    china  2016    3     43
# 22065  94    PIT    109.444  43    Soft    china  2016    3     43
# 22066  94   1 LAP   122.488  44   Super    china  2016    3     12
# 22067  94   1 LAP   101.969  45   Super    china  2016    3     12
# 22068  94   1 LAP   103.061  46   Super    china  2016    3     12
# 22069  94   1 LAP   101.997  47   Super    china  2016    3     12
# 22070  94   1 LAP   101.489  48   Super    china  2016    3     12
# 22071  94   1 LAP   101.848  49   Super    china  2016    3     12
# 22072  94   1 LAP   101.726  50   Super    china  2016    3     12
# 22073  94   1 LAP   101.844  51   Super    china  2016    3     12
# 22074  94   1 LAP   102.088  52   Super    china  2016    3     12
# 22075  94   1 LAP   102.412  53   Super    china  2016    3     12
# 22076  94   1 LAP   103.036  54   Super    china  2016    3     12
# 22077  94   1 LAP   103.517  55   Super    china  2016    3     12
#
#          TIME_AVG   TIME_STD
# 0       93.847187  13.835873
# 1       93.847187  13.835873
# 2       93.847187  13.835873
# 3       93.847187  13.835873
# 4       93.847187  13.835873
# 5       93.847187  13.835873
# 6       93.847187  13.835873
# 7       93.847187  13.835873
# 8       93.847187  13.835873
# 9       93.847187  13.835873
# 10      93.847187  13.835873
# 11      93.847187  13.835873
# 12      93.847187  13.835873
# 13      93.847187  13.835873
# 14      93.847187  13.835873
# 15      93.847187  13.835873
# 16      93.847187  13.835873
# 17      93.847187  13.835873
# 18      93.847187  13.835873
# 19      93.847187  13.835873
# 20      93.847187  13.835873
# 21      90.019238   4.462424
# 22      90.019238   4.462424
# 23      90.019238   4.462424
# 24      90.019238   4.462424
# 25      90.019238   4.462424
# 26      90.019238   4.462424
# 27      90.019238   4.462424
# 28      90.019238   4.462424
# 29      90.019238   4.462424
# ...           ...        ...
# 22048  109.709302  12.008003
# 22049  109.709302  12.008003
# 22050  109.709302  12.008003
# 22051  109.709302  12.008003
# 22052  109.709302  12.008003
# 22053  109.709302  12.008003
# 22054  109.709302  12.008003
# 22055  109.709302  12.008003
# 22056  109.709302  12.008003
# 22057  109.709302  12.008003
# 22058  109.709302  12.008003
# 22059  109.709302  12.008003
# 22060  109.709302  12.008003
# 22061  109.709302  12.008003
# 22062  109.709302  12.008003
# 22063  109.709302  12.008003
# 22064  109.709302  12.008003
# 22065  109.709302  12.008003
# 22066  103.956250   5.869006
# 22067  103.956250   5.869006
# 22068  103.956250   5.869006
# 22069  103.956250   5.869006
# 22070  103.956250   5.869006
# 22071  103.956250   5.869006
# 22072  103.956250   5.869006
# 22073  103.956250   5.869006
# 22074  103.956250   5.869006
# 22075  103.956250   5.869006
# 22076  103.956250   5.869006
# 22077  103.956250   5.869006
#
# [21713 rows x 11 columns]

# %%
lap_features = pd.merge(avg_laps, tracks, how='left', on=['TRACK', 'YEAR'])
lap_features['TIRE_VAL'] = lap_features['TIRE'].apply(assign_ordinal)
lap_features.head()

# %%
regression_features = lap_features.drop(['NO', 'TIRE', 'TRACK', 'YEAR', 'T_TEMP_MIN'], axis=1)
regression_features.info()

# %%
y = regression_features.pop('TIME_AVG')
y;

# %%
X = regression_features
X;

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
model = sms.OLS(y_train, X_train).fit()
summary = model.summary()

# %%
summary

# %%
y_predict = model.predict(X_test)

# %%
# model.score(y_predict, y_test)

# %% [markdown]
# ### Sklearn LinearReg Model, no cross val

# %%
linear = LinearRegression()
linear.fit(X_train, y_train)
linear.score(X_train, y_train)

# %%
y_predict = linear.predict(X_test)
linear.score(X_test, y_test)

# %%
zip(y_predict, y_test)

# %% [markdown]
# ### Sklearn LinearReg Model, no cross val

# %%
linear_cv = cross_val_score(linear, X, y, scoring='r2', cv=5)
linear_cv

# %% [markdown]
# ### RandomForestRegressor

# %%
rfr = RandomForestRegressor(n_estimators=15, max_features='auto', oob_score=True)

# %%
rfr.fit(X_train, y_train)

# %%
rfr.oob_score_

# %%
zip(rfr.oob_prediction_, rfr.predict(X_test), y_test)

# %%
rfr.score(X_train, y_train)

# %%
rfr.score(X_test, y_test)

# %% [markdown]
# ### AdaBoostRegressor

# %%
abr = AdaBoostRegressor(base_estimator=rfr, n_estimators=400, learning_rate=.01, loss='square')

# %%
abr.fit(X_train, y_train)

# %%
abr.score(X_train, y_train)

# %%
abr.score(X_test, y_test)

# %% [markdown]
# ## Plot All Lap times vs Lap, Labeled by Tire type

# %%
hungary_2015 = all_lap_times[(all_lap_times['TRACK'] == 'hungary') & (all_lap_times['YEAR'] == 2015)]
hungary_2015

# %%
def plot_drivers(df, race):
    year, race_num, track = race.split('_')
    this_race = df[(df['TRACK'] == track) & (df['YEAR'] == int(year))]
    for num in this_race['NO'].unique():
        driver_idx = this_race['NO'] == num
        plt.figure(figsize=(12,6))
        plt.title('{} {} - Driver No. {}'.format(track.upper(), year, num))
        plt.xlim([0, this_race['LAP'].max() + 1])
        plt.scatter(this_race['LAP'][driver_idx], this_race['TIME'][driver_idx], c=this_race['TIRE'][driver_idx].apply(assign_color), alpha=1)
    plt.show()
    
def plot_race(df, race):
    year, race_num, track = race.split('_')
    this_race = df[(df['TRACK'] == track) & (df['YEAR'] == int(year))]
    plt.figure(figsize=(12,6))
    plt.title('{} {}'.format(track.upper(), year))
    plt.xlim([0, this_race['LAP'].max() + 1])
    plt.scatter(this_race['LAP'], this_race['TIME'], c=this_race['TIRE'].apply(assign_color), alpha=.5)
    plt.show()

# %%
plot_drivers(clean_df, '2016_1_australia')

# %%
for race in races:
    plot_race(clean_df, race)

# %%
clean_df[clean_df['TIME'] > 250]
# Out:
#        NO      GAP      TIME LAP  TIRE      TRACK  YEAR RACE  COUNT  \
# 1926   55   1 LAP    347.531   1  Soft    belgium  2015   11     10
# 19102   9    PIT    1222.582  18  Soft  australia  2016    1      7
# 19197  12    PIT    1222.819  18  Soft  australia  2016    1      8
# 19269  19    PIT    1243.269  18  Soft  australia  2016    1      7
# 19325  20    PIT     729.123  17  Soft  australia  2016    1     17
# 19326  20  103.716   500.454  18  Soft  australia  2016    1     17
# 19512  30    PIT    1223.356  18  Soft  australia  2016    1      6
#
#          TIME_AVG    TIME_STD
# 1926   144.963400   71.529149
# 19102  259.874857  424.626946
# 19197  239.275875  397.537851
# 19269  260.915143  433.232296
# 19325  160.337706  176.026583
# 19326  160.337706  176.026583
# 19512  286.968167  458.847103

# %%
avg_laps['TIRE_VAL'] = avg_laps['TIRE'].apply(assign_ordinal)
avg_laps.head()

# %%
# sn.pairplot(avg_laps[['COUNT', 'TIME', 'TIRE_VAL']])

# %%
plt.scatter(avg_laps['COUNT'], avg_laps['TIME_AVG'], c=avg_laps['TIRE'].apply(assign_color), alpha=.5)
# plt.xlim([0, 50])
# plt.ylim([50,200])

# %% [markdown]
# ## TEST CODE BELOW
