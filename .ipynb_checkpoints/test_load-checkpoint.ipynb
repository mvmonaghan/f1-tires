# %%
import pandas as pd
import numpy as np
import datetime
import os


def assign_lap(df):
    df['LAP'] = 1
    cols = ['NO', 'GAP', 'TIME', 'LAP']
    drivers = df[0].unique()
    data = df.values
    for driver in drivers:
        data[data[:,0] == driver, 3] = data[data[:,0] == driver, 3].cumsum()
    return pd.DataFrame(data=data, columns=cols)

def get_strategies(df):
    arr = df.values
    all_strategies = []
    for row in arr:
        strategy = [row[0]]
        for item in row[1:]:
            try:
                tire, laps = item.split()
                laps = int(laps.replace('(', '').replace(')', ''))
                stint = []
                for i in xrange(laps):
                    stint.append(tire)
                strategy.extend(stint)
            except:
                pass
        all_strategies.append(strategy)
    df = pd.DataFrame(data=all_strategies)
    column_names = ['NAME']
    column_names.extend([i for i in xrange(1, df.shape[1])])
    df.columns = column_names
    return df

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# /Users/milesmonaghan/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
# Load driver list for particular season
driver_list = pd.read_csv('data/2016_drivers.csv')

# %%
# Load lap times for all drivers
df = pd.read_csv('data/2016_1_austrailia/tabula-2016_1_lap_history.csv', header=None)
df = assign_lap(df)
df.sort_values(by=['NO', 'LAP'], inplace=True)
df[df['NO'] == 20]
# Out:
#       NO      GAP       TIME LAP
# 20    20    PIT     3:00.423   1
# 45    20   1 LAP    1:46.207   2
# 69    20   1 LAP    1:37.229   3
# 90    20   1 LAP    1:34.720   4
# 112   20   1 LAP    1:35.346   5
# 141   20   1 LAP    1:43.453   6
# 161   20   1 LAP    1:34.917   7
# 182   20   1 LAP    1:35.742   8
# 203   20   1 LAP    1:35.633   9
# 224   20   1 LAP    1:37.304  10
# 243   20   1 LAP    1:37.254  11
# 264   20   1 LAP    1:35.206  12
# 285   20   1 LAP    1:34.927  13
# 307   20   1 LAP    1:37.999  14
# 327   20   1 LAP    1:35.084  15
# 350   20    PIT     2:15.143  16
# 359   20    PIT    12:09.123  17
# 372   20  103.716   8:20.454  18
# 390   20  10.856    2:00.667  19
# 408   20  16.333    1:36.001  20
# 425   20  21.513    1:35.554  21
# 442   20  24.759    1:33.453  22
# 459   20  29.632    1:34.824  23
# 476   20  34.260    1:34.813  24
# 492   20  39.133    1:35.592  25
# 509   20  42.018    1:34.649  26
# 525   20  45.126    1:34.562  27
# 542   20  47.631    1:34.012  28
# 559   20  49.549    1:33.727  29
# 575   20  51.085    1:33.539  30
# 592   20  52.365    1:33.508  31
# 609   20  53.723    1:33.585  32
# 626   20  54.766    1:33.838  33
# 643   20  55.547    1:33.718  34
# 660   20  54.770    1:33.306  35
# 677   20  55.792    1:33.004  36
# 694   20  56.826    1:32.789  37
# 711   20  57.941    1:32.783  38
# 728   20  58.595    1:32.791  39
# 744   20  60.188    1:33.244  40
# 760   20  61.002    1:33.320  41
# 776   20  62.300    1:32.765  42
# 792   20  63.945    1:32.715  43
# 808   20  66.107    1:33.016  44
# 824   20  67.747    1:32.452  45
# 840   20  69.129    1:32.797  46
# 856   20  70.366    1:32.459  47
# 872   20  71.881    1:32.815  48
# 888   20  73.093    1:33.023  49
# 904   20  75.949    1:33.856  50
# 920   20  78.095    1:32.849  51
# 936   20  80.301    1:33.184  52
# 952   20  81.495    1:33.007  53
# 968   20  82.886    1:33.570  54
# 983   20  83.778    1:33.242  55
# 999   20  84.712    1:32.635  56
# 1014  20  85.606    1:33.343  57

# %%
print df.NO.unique()
print df.info()
# Out:
# [3 5 6 7 8 9 11 12 14 19 20 21 22 27 30 33 44 55 77 88 94]
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1017 entries, 8 to 1015
# Data columns (total 4 columns):
# NO      1017 non-null object
# GAP     1017 non-null object
# TIME    1017 non-null object
# LAP     1017 non-null object
# dtypes: object(4)
# memory usage: 39.7+ KB
# None

# %%
# for num in df.NO.unique():
#     print 'Number: ', num
#     print df[df['NO'] == num].shape

# %%
# Convert lap time to seconds
df['TIME'] = df['TIME'].apply(lambda x: x.strip())
df['TIME'] = df['TIME'].apply(lambda x: datetime.datetime.strptime(x,'%M:%S.%f'))
df['timedelta'] = df.TIME - datetime.datetime.strptime('00:00.0','%M:%S.%f')
df['secs'] = df['timedelta'].apply(lambda x: x / np.timedelta64(1, 's'))
df.head()
df.drop(['TIME', 'timedelta'], axis=1, inplace=True)

# %%
# Load Tire strategy data
tire_data = pd.read_csv('data/2016_1_austrailia/2016_1_tires.csv')
tire_strat = get_strategies(tire_data)

# %%
tire_strat.head()
# Out:
#                NAME      1      2      3      4      5      6      7      8  \
# 0      Nico Rosberg  Super  Super  Super  Super  Super  Super  Super  Super
# 1    Lewis Hamilton  Super  Super  Super  Super  Super  Super  Super  Super
# 2  Sebastian Vettel  Super  Super  Super  Super  Super  Super  Super  Super
# 3  Daniel Ricciardo  Super  Super  Super  Super  Super  Super  Super  Super
# 4      Felipe Massa  Super  Super  Super  Super  Super  Super  Super  Super
#
#        9   ...        48      49      50      51      52      53      54  \
# 0  Super   ...    Medium  Medium  Medium  Medium  Medium  Medium  Medium
# 1  Super   ...    Medium  Medium  Medium  Medium  Medium  Medium  Medium
# 2  Super   ...      Soft    Soft    Soft    Soft    Soft    Soft    Soft
# 3  Super   ...     Super   Super   Super   Super   Super   Super   Super
# 4  Super   ...    Medium  Medium  Medium  Medium  Medium  Medium  Medium
#
#        55      56      57
# 0  Medium  Medium  Medium
# 1  Medium  Medium  Medium
# 2    Soft    Soft    Soft
# 3   Super   Super   Super
# 4  Medium  Medium  Medium
#
# [5 rows x 58 columns]

# %%
tire_strat = pd.merge(driver_list, tire_strat, on='NAME')
tire_strat.drop(['NAME', 'DRIVER'], axis=1, inplace=True)

# %%
tire_strat
# Out:
#     NO      1      2      3      4      5      6      7      8      9   ...    \
# 0    3  Super  Super  Super  Super  Super  Super  Super  Super  Super   ...
# 1    5  Super  Super  Super  Super  Super  Super  Super  Super  Super   ...
# 2    6  Super  Super  Super  Super  Super  Super  Super  Super  Super   ...
# 3    7  Super  Super  Super  Super  Super  Super  Super  Super  Super   ...
# 4    8   Soft   Soft   Soft   Soft   Soft   Soft   Soft   Soft   Soft   ...
# 5    9  Super  Super  Super  Super  Super  Super  Super  Super  Super   ...
# 6   11   Soft   Soft   Soft   Soft   Soft   Soft   Soft   Soft   Soft   ...
# 7   12  Super  Super  Super  Super  Super  Super  Super  Super  Super   ...
# 8   14  Super  Super  Super  Super  Super  Super  Super  Super  Super   ...
# 9   19  Super  Super  Super  Super  Super  Super  Super  Super  Super   ...
# 10  20  Super   Soft   Soft   Soft   Soft   Soft   Soft   Soft   Soft   ...
# 11  21   Soft   Soft   Soft   Soft   Soft   Soft   Soft   Soft   Soft   ...
# 12  22   Soft   Soft   Soft   Soft   Soft   Soft   Soft   Soft   Soft   ...
# 13  27   Soft   Soft   Soft   Soft   Soft   Soft   Soft   Soft   Soft   ...
# 14  30  Super  Super  Super  Super  Super  Super  Super  Super  Super   ...
# 15  33  Super  Super  Super  Super  Super  Super  Super  Super  Super   ...
# 16  44  Super  Super  Super  Super  Super  Super  Super  Super  Super   ...
# 17  55  Super  Super  Super  Super  Super  Super  Super  Super   Soft   ...
# 18  77   Soft   Soft   Soft   Soft   Soft   Soft   Soft   Soft   Soft   ...
# 19  88  Super  Super  Super  Super  Super  Super  Super  Super  Super   ...
# 20  94  Super  Super  Super  Super  Super  Super  Super  Super  Super   ...
#
#         48      49      50      51      52      53      54      55      56  \
# 0    Super   Super   Super   Super   Super   Super   Super   Super   Super
# 1     Soft    Soft    Soft    Soft    Soft    Soft    Soft    Soft    Soft
# 2   Medium  Medium  Medium  Medium  Medium  Medium  Medium  Medium  Medium
# 3     None    None    None    None    None    None    None    None    None
# 4   Medium  Medium  Medium  Medium  Medium  Medium  Medium  Medium  Medium
# 5     None    None    None    None    None    None    None    None    None
# 6   Medium  Medium  Medium  Medium  Medium  Medium  Medium  Medium  Medium
# 7   Medium  Medium  Medium  Medium  Medium  Medium  Medium  Medium  Medium
# 8     None    None    None    None    None    None    None    None    None
# 9   Medium  Medium  Medium  Medium  Medium  Medium  Medium  Medium  Medium
# 10  Medium  Medium  Medium  Medium  Medium  Medium  Medium  Medium  Medium
# 11    None    None    None    None    None    None    None    None    None
# 12  Medium  Medium  Medium  Medium  Medium  Medium  Medium  Medium  Medium
# 13  Medium  Medium  Medium  Medium  Medium  Medium  Medium  Medium  Medium
# 14  Medium  Medium  Medium  Medium  Medium  Medium  Medium  Medium  Medium
# 15  Medium  Medium  Medium  Medium  Medium  Medium  Medium  Medium  Medium
# 16  Medium  Medium  Medium  Medium  Medium  Medium  Medium  Medium  Medium
# 17  Medium  Medium  Medium  Medium  Medium  Medium  Medium  Medium  Medium
# 18  Medium  Medium  Medium  Medium  Medium  Medium  Medium  Medium  Medium
# 19    None    None    None    None    None    None    None    None    None
# 20  Medium  Medium  Medium  Medium  Medium  Medium  Medium  Medium  Medium
#
#         57
# 0    Super
# 1     Soft
# 2   Medium
# 3     None
# 4   Medium
# 5     None
# 6   Medium
# 7     None
# 8     None
# 9   Medium
# 10  Medium
# 11    None
# 12    None
# 13  Medium
# 14  Medium
# 15  Medium
# 16  Medium
# 17  Medium
# 18  Medium
# 19    None
# 20    None
#
# [21 rows x 58 columns]

# %%
mask = new.iloc[:,1:].notnull().values

# %%
df['TIRE'] = tire_strat[tire_strat.columns[1:]].values[mask].flatten()

# %%
df.head()
# Out:
#    NO      GAP LAP     secs   TIRE
# 8   3   6.860    1  103.776  Super
# 29  3   9.466    2   94.270  Super
# 50  3  11.249    3   93.950  Super
# 71  3  13.149    4   93.914  Super
# 91  3  13.891    5   93.015  Super

# %%
ric = df[['LAP', 'secs']][(df['NO'] == 3) & (df['LAP'] > 42)]
print ric
plt.plot(ric['LAP'], ric['secs'])
# Out:
#      LAP    secs
# 784   43  97.426
# 800   44  90.048
# 816   45  91.138
# 831   46  89.965
# 847   47  89.466
# 862   48  89.420
# 878   49  88.997
# 894   50  89.307
# 910   51  90.299
# 926   52  90.365
# 942   53  90.390
# 958   54  90.953
# 974   55  91.776
# 990   56  91.794
# 1006  57  94.766

# %%
ros = df[['LAP', 'secs']][(df['NO'] == 6) & (df['LAP'] > 19)]
print ros
plt.plot(ros['LAP'], ros['secs'])
# Out:
#      LAP    secs
# 392   20  91.206
# 410   21  90.557
# 428   22  90.688
# 445   23  90.939
# 462   24  90.901
# 479   25  90.929
# 496   26  90.931
# 513   27  91.369
# 530   28  91.691
# 547   29  91.899
# 564   30  91.800
# 581   31  91.885
# 598   32  91.813
# 615   33  92.115
# 632   34  92.685
# 648   35  92.679
# 665   36  91.982
# 682   37  91.755
# 699   38  91.668
# 715   39  92.137
# 731   40  91.651
# 747   41  92.506
# 763   42  91.467
# 779   43  91.070
# 795   44  90.854
# 811   45  90.812
# 827   46  91.415
# 843   47  91.222
# 859   48  91.300
# 875   49  91.811
# 891   50  91.000
# 907   51  90.703
# 923   52  90.978
# 939   53  91.813
# 954   54  92.179
# 969   55  92.350
# 985   56  91.701
# 1001  57  92.449
