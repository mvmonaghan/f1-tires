# %%
import pandas as pd
import numpy as np
import statsmodels.api as sms
from sklearn.linear_model import LinearRegression
from sklearn.cross_validation import KFold
from sklearn.cross_validation import train_test_split
from sklearn.cross_validation import cross_val_score

# %%
import matplotlib.pyplot as plt
import seaborn as sn
# %matplotlib inline

# %%
df = pd.read_csv('data/track_profiles - Sheet1.csv')

# %%
df.head()
# Out:
#          NAME  YEAR  LENGTH  LAPS  DOWNFORCE  LATERAL  ASPHALT_ABR  \
# 0  Austrailia  2016    5.30    58          4        1            3
# 1     Bahrain  2016    5.41    57          3        3            5
# 2       China  2016    5.45    56          3        4            3
# 3  Austrailia  2015    5.30    58          4        1            3
# 4    Malaysia  2015    5.54    56          3        4            3
#
#    ASPHALT_GRP  TIRE_STRESS  AIR_TEMP_MAX  AIR_TEMP_MIN  T_TEMP_MAX  \
# 0            1            1          24.7          22.2        38.4
# 1            4            3          22.6          21.2        29.6
# 2            3            4          21.9          20.3        37.3
# 3            1            1          21.0          17.0        38.0
# 4            3            4          35.4          32.7        61.4
#
#    T_TEMP_MIN  SECTOR_1  TIME_1  SECTOR_2  TIME_2  SECTOR_3  TIME_3  TIRE
# 0        26.8       NaN     NaN       NaN     NaN       NaN     NaN   NaN
# 1        25.9       NaN     NaN       NaN     NaN       NaN     NaN   NaN
# 2        45.3       NaN     NaN       NaN     NaN       NaN     NaN   NaN
# 3        29.0       NaN     NaN       NaN     NaN       NaN     NaN   NaN
# 4        53.0       NaN     NaN       NaN     NaN       NaN     NaN   NaN

# %%
X = df[df.columns[2:13]]
X
# Out:
#     LENGTH  LAPS  DOWNFORCE  LATERAL  ASPHALT_ABR  ASPHALT_GRP  TIRE_STRESS  \
# 0     5.30    58          4        1            3            1            1
# 1     5.41    57          3        3            5            4            3
# 2     5.45    56          3        4            3            3            4
# 3     5.30    58          4        1            3            1            1
# 4     5.54    56          3        4            3            3            4
# 5     5.45    56          3        4            3            3            4
# 6     4.65    66          4        4            4            4            4
# 7     3.34    78          5        1            1            1            1
# 8     4.36    70          2        1            1            1            2
# 9     4.33    71          4        3            1            2            2
# 10    5.89    52          4        5            3            4            5
# 11    4.38    70          4        4            3            4            3
# 12    7.00    44          2        4            3            4            5
# 13    5.79    53          1        2            3            2            5
# 14    5.06    61          5        2            3            1            2
# 15    5.80    53          3        5            3            4            5
# 16    5.84    53          4        5            1            4            2
# 17    5.51    56          3        4            3            2            3
# 18    4.30    71          2        3            0            4            0
# 19    4.30    71          4        4            3            3            3
# 20    5.55    55          3        3            2            2            2
#
#     AIR_TEMP_MAX  AIR_TEMP_MIN  T_TEMP_MAX  T_TEMP_MIN
# 0           24.7          22.2        38.4        26.8
# 1           22.6          21.2        29.6        25.9
# 2           21.9          20.3        37.3        45.3
# 3           21.0          17.0        38.0        29.0
# 4           35.4          32.7        61.4        53.0
# 5           22.2          20.5        46.6        40.3
# 6           28.3          25.3        51.9        45.6
# 7           19.4          18.0        40.1        31.5
# 8           22.0          20.2        42.3        37.6
# 9           16.0          14.0        35.6        27.1
# 10          20.6          17.3        38.9        23.9
# 11          24.9          22.0        49.2        40.7
# 12          23.0          22.0        37.0        33.0
# 13          23.0          22.0        39.0        38.0
# 14          30.3          28.7        37.4        33.5
# 15          28.6          27.2        42.4        35.3
# 16          18.8          17.9        28.0        25.6
# 17          17.8          17.2        19.4        17.8
# 18          25.2          22.1        56.5        42.3
# 19          25.8          22.1        47.3        38.2
# 20          27.0          25.1        29.3        27.5

# %%
sn.pairplot(X)
